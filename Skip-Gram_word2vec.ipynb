# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
def sub_sampling(int_words, threshold):
    word_occur = Counter(int_words)
    total = len(int_words)
    freq= {word: count/total for word,count in word_occur.items()}
    drop ={word:(1-np.sqrt(threshold/ freq[word])) for word in word_occur}
    trained_words = [word for word in int_words if drop[word]<np.random.random()]
    return trained_words
train_words = sub_sampling(int_words,0.00001)
# The final subsampled word list
len(train_words)
# Out:
# 4627231

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R=np.random.randint(1,window_size+1)
    # Your code here
    start= idx-R if idx-R>0 else 0
    end=idx+R
    target=set(words[start:idx]+words[idx+1:end+1])
    return list(target)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None],name='inputs')
    labels = tf.placeholder(tf.int32,[None,None],name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding], minval=-1, maxval=1, dtype=tf.float32 )) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.random.normal([n_vocab,n_embedding],stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7187 0.2229 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.7014 0.2063 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5552 0.2032 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6683 0.2006 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5696 0.2153 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6148 0.2171 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6241 0.2420 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5882 0.2278 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5179 0.2162 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5087 0.1987 sec/batch
# Nearest to had: pasiphae, mockingly, reconstructions, prepared, dominatrixes, normans, frenchman, enlighten,
# Nearest to he: strains, humane, virchow, configure, bling, jnana, kumquat, polgar,
# Nearest to up: endangering, ria, gondor, boldness, johnsen, bunyips, toaster, picatinny,
# Nearest to or: probes, quixote, secularism, periphery, bomarc, skeeter, movements, vocal,
# Nearest to no: remade, inhalants, canmore, divan, mcintosh, poverty, fate, tandy,
# Nearest to who: purse, ffg, homoerotic, tillich, carcinogenic, telnet, bletchley, hotspur,
# Nearest to there: eurocheque, turkic, wrangler, jimmy, ideologue, winfield, jitter, saw,
# Nearest to be: acquire, isomorphic, inwards, marquise, famine, gernsback, lazare, strawberries,
# Nearest to engineering: gestational, subroutines, miscegenation, impulses, lukewarm, unholy, pin, mennonite,
# Nearest to instance: brotherhood, aspirin, seaport, easily, mash, carina, solicitor, northrop,
# Nearest to egypt: gtc, reynolds, proletarian, exception, kulm, macho, livelihood, assumption,
# Nearest to report: numismatics, correspondance, dra, kovacs, wai, andrea, stylish, geese,
# Nearest to accepted: mcghee, memeplex, jovis, farnham, cheddar, mcbride, plazas, myth,
# Nearest to numerous: cathode, hmas, autosomal, masters, fachhochschule, noradrenaline, calixtus, farrell,
# Nearest to cost: rissa, dummy, plowman, shingon, thabit, gracious, inviolable, nostradamus,
# Nearest to orthodox: unusable, probl, fans, eccleston, karaites, unequalled, inflection, donoghue,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5365 0.2103 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4303 0.2205 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3992 0.2167 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3297 0.2153 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2537 0.2067 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2350 0.1992 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1755 0.1992 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1155 0.1992 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0859 0.2098 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0440 0.2071 sec/batch
# Nearest to had: called, pasiphae, prepared, mockingly, reconstructions, enlighten, foremost, frenchman,
# Nearest to he: available, humane, strains, configure, very, doctors, adults, virchow,
# Nearest to up: endangering, diphthong, ticket, gondor, evil, holiday, incorporate, johnsen,
# Nearest to or: probes, places, movements, quixote, periphery, atomic, vocal, bomarc,
# Nearest to no: poverty, inhalants, filming, canmore, remade, fate, learning, marketed,
# Nearest to who: purse, st, zero, mb, mechanism, transpose, carcinogenic, inside,
# Nearest to there: eurocheque, saw, turkic, jimmy, c, ideologue, replaced, wrangler,
# Nearest to be: isomorphic, acquire, famine, native, assist, doubt, inwards, see,
# Nearest to engineering: impulses, pin, subroutines, gestational, zero, epsilon, unholy, lukewarm,
# Nearest to instance: brotherhood, easily, aspirin, second, remained, solicitor, mash, seaport,
# Nearest to egypt: gtc, exception, reynolds, proletarian, assumption, livelihood, major, trademark,
# Nearest to report: numismatics, correspondance, dra, andrea, kovacs, stylish, successors, wai,
# Nearest to accepted: myth, nations, mcghee, radioactivity, memeplex, plains, farnham, jovis,
# Nearest to numerous: cathode, hmas, fachhochschule, autosomal, masters, synthesized, alternating, artists,
# Nearest to cost: theological, dummy, kids, rissa, edmond, ziegfeld, thabit, plowman,
# Nearest to orthodox: unusable, fans, probl, inflection, eccleston, axiom, denomination, henson,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.0190 0.2108 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9736 0.2057 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9280 0.2005 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9205 0.2125 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8547 0.2185 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8686 0.2148 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8466 0.1999 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8285 0.2006 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8233 0.1972 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8392 0.2081 sec/batch
# Nearest to had: called, mockingly, pasiphae, prepared, foremost, lyons, accepted, frenchman,
# Nearest to he: humane, strains, virchow, doctors, matters, s, crunch, configure,
# Nearest to up: endangering, ticket, evil, gondor, diphthong, affiliation, anti, tremble,
# Nearest to or: probes, quixote, detailing, recall, vocal, places, block, periphery,
# Nearest to no: poverty, remade, septuagint, inhalants, fate, canmore, tandy, bonfire,
# Nearest to who: purse, causality, sino, telnet, paris, st, transpose, occur,
# Nearest to there: eurocheque, turkic, jimmy, ideologue, circumvent, spawned, economies, permits,
# Nearest to be: isomorphic, famine, doubt, assist, acquire, puts, victories, inwards,
# Nearest to engineering: impulses, pin, zero, subroutines, epsilon, gestational, calendar, unholy,
# Nearest to instance: brotherhood, easily, second, aspirin, remained, solicitor, seaport, northrop,
# Nearest to egypt: exception, gtc, reynolds, major, assumption, livelihood, proletarian, trademark,
# Nearest to report: correspondance, numismatics, dra, andrea, successors, relocated, wai, kovacs,
# Nearest to accepted: nations, myth, had, plains, radioactivity, jovis, separation, bundled,
# Nearest to numerous: hmas, cathode, fachhochschule, masters, autosomal, uncertain, raven, heightened,
# Nearest to cost: dummy, theological, kids, edmond, thabit, rissa, badges, plowman,
# Nearest to orthodox: unusable, fans, probl, axiom, eccleston, inflection, denomination, mandy,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8111 0.2032 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8014 0.2064 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7593 0.1973 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7744 0.1962 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.8008 0.1972 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7305 0.2020 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7399 0.2129 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7851 0.1999 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7494 0.1963 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6969 0.2113 sec/batch
# Nearest to had: mockingly, pasiphae, called, foremost, prepared, frenchman, lawrence, accepted,
# Nearest to he: humane, virchow, strains, kate, keswick, s, meditate, father,
# Nearest to up: endangering, ticket, gondor, affiliation, healed, diphthong, evil, rotated,
# Nearest to or: probes, quixote, recall, periphery, block, shutting, psychotic, detailing,
# Nearest to no: septuagint, inhalants, poverty, remade, tandy, canmore, prescott, wares,
# Nearest to who: purse, homoerotic, causality, st, arrested, paris, sino, removing,
# Nearest to there: eurocheque, turkic, ideologue, circumvent, kalmar, permits, wrangler, dupont,
# Nearest to be: isomorphic, puts, famine, solicits, acquire, doubt, deflation, assist,
# Nearest to engineering: impulses, pin, gestational, unholy, lukewarm, subroutines, miscegenation, crimea,
# Nearest to instance: easily, brotherhood, aspirin, second, seaport, remained, solicitor, preprocessor,
# Nearest to egypt: gtc, reynolds, proletarian, exception, major, gutted, assumption, livelihood,
# Nearest to report: numismatics, correspondance, dra, wai, andrea, piper, relocated, successors,
# Nearest to accepted: myth, nations, plains, had, jovis, radioactivity, mcghee, bundled,
# Nearest to numerous: hmas, fachhochschule, masters, cathode, autosomal, mosul, hark, uncertain,
# Nearest to cost: dummy, rissa, inviolable, theological, microbiologist, kids, shingon, badges,
# Nearest to orthodox: unusable, probl, fans, unequalled, axiom, retarded, denomination, mandy,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7140 0.2001 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6615 0.1978 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6488 0.2081 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6381 0.2068 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6831 0.2050 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6577 0.1973 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6037 0.1435 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.6095 0.1965 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5465 0.1964 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5472 0.1969 sec/batch
# Nearest to had: mockingly, pasiphae, foremost, called, honneur, normans, sisters, lawrence,
# Nearest to he: humane, virchow, father, strains, oilers, theophylline, chand, polgar,
# Nearest to up: endangering, gondor, ticket, diphthong, rotated, healed, tanoana, picatinny,
# Nearest to or: probes, mnemonic, arguments, recall, detailing, hmso, block, shutting,
# Nearest to no: tandy, inhalants, septuagint, remade, wares, divan, poverty, canmore,
# Nearest to who: purse, homoerotic, arrested, causality, paris, st, battle, sino,
# Nearest to there: eurocheque, turkic, ideologue, circumvent, dupont, enclosure, grunt, wrangler,
# Nearest to be: isomorphic, solicits, acquire, deflation, floating, famine, doubt, puts,
# Nearest to engineering: pin, impulses, gestational, unholy, fujiwara, exemplify, lukewarm, epsilon,
# Nearest to instance: easily, aspirin, brotherhood, preprocessor, seaport, remained, quantities, hafiz,
# Nearest to egypt: proletarian, gtc, major, gutted, exception, reynolds, voyager, macho,
# Nearest to report: numismatics, correspondance, dra, piper, wai, gallon, relocated, andrea,
# Nearest to accepted: myth, jovis, nations, plains, radioactivity, farnham, had, ei,
# Nearest to numerous: masters, hmas, fachhochschule, cathode, autosomal, somerville, hark, sintering,
# Nearest to cost: dummy, rissa, inviolable, shingon, microbiologist, plowman, dojo, gracious,
# Nearest to orthodox: unusable, probl, unequalled, hereford, retarded, mandy, fans, denomination,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5367 0.1976 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5066 0.1967 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4913 0.1965 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5544 0.1966 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5151 0.1963 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4922 0.1962 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4784 0.1990 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4240 0.2087 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4487 0.2048 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4661 0.1982 sec/batch
# Nearest to had: pasiphae, mockingly, foremost, honneur, normans, cursed, called, killed,
# Nearest to he: virchow, humane, father, matters, oilers, theophylline, polgar, adamawa,
# Nearest to up: endangering, gondor, diphthong, revel, tanoana, ticket, rotated, chronica,
# Nearest to or: probes, arguments, block, mnemonic, bomarc, shutting, hmso, detailing,
# Nearest to no: septuagint, tandy, inhalants, divan, poverty, wares, remade, mcintosh,
# Nearest to who: homoerotic, purse, arrested, causality, battle, authority, paris, sino,
# Nearest to there: eurocheque, turkic, less, grunt, circumvent, dupont, ideologue, enclosure,
# Nearest to be: isomorphic, solicits, floating, acquire, deflation, this, puts, grasp,
# Nearest to engineering: pin, impulses, exemplify, unholy, gestational, buyer, fujiwara, cousteau,
# Nearest to instance: easily, aspirin, brotherhood, preprocessor, second, quantities, hafiz, setup,
# Nearest to egypt: proletarian, gutted, major, gtc, exception, aboriginal, toontown, geist,
# Nearest to report: numismatics, correspondance, dra, piper, wai, gallon, madre, andrea,
# Nearest to accepted: myth, nations, jovis, cheddar, radioactivity, farnham, had, plains,
# Nearest to numerous: masters, hmas, fachhochschule, cathode, uncertain, sintering, autosomal, abdicates,
# Nearest to cost: dummy, rissa, shingon, inviolable, microbiologist, dojo, plowman, gracious,
# Nearest to orthodox: unusable, probl, unequalled, denomination, hereford, retarded, mandy, forbidden,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4775 0.2081 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4459 0.2121 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4753 0.2023 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4265 0.2093 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4574 0.2083 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4756 0.2086 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4086 0.2075 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4186 0.2112 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4280 0.2072 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4116 0.2089 sec/batch
# Nearest to had: pasiphae, mockingly, cursed, sisters, foremost, called, normans, killed,
# Nearest to he: father, virchow, humane, man, theophylline, polgar, matters, kate,
# Nearest to up: endangering, gondor, revel, chronica, ticket, cossacks, picatinny, toaster,
# Nearest to or: probes, mnemonic, bomarc, hmso, apparent, arguments, block, shutting,
# Nearest to no: septuagint, tandy, divan, wares, mcintosh, poverty, elfland, inhalants,
# Nearest to who: purse, homoerotic, arrested, causality, authority, adolescent, paris, sino,
# Nearest to there: eurocheque, turkic, grunt, less, circumvent, kalmar, aran, analyses,
# Nearest to be: isomorphic, solicits, grasp, deflation, proofs, this, conducting, puts,
# Nearest to engineering: pin, impulses, exemplify, buyer, unholy, enhancements, gestational, stalwart,
# Nearest to instance: easily, aspirin, brotherhood, second, preprocessor, hafiz, quantities, setup,
# Nearest to egypt: proletarian, major, gutted, exception, gtc, toontown, voyager, geist,
# Nearest to report: numismatics, correspondance, dra, wai, piper, gallon, madre, relocated,
# Nearest to accepted: myth, jovis, nations, cheddar, says, seeking, radioactivity, farnham,
# Nearest to numerous: hmas, sintering, masters, fachhochschule, uncertain, synthesized, cathode, fgm,
# Nearest to cost: dummy, rissa, inviolable, microbiologist, dojo, shingon, plowman, coherence,
# Nearest to orthodox: denomination, unequalled, worship, probl, unusable, hereford, oriental, ecumenical,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3890 0.2181 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4147 0.2077 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.4162 0.2179 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3882 0.1962 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4130 0.2217 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3969 0.2300 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4150 0.2338 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4262 0.2251 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3414 0.2140 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3751 0.2172 sec/batch
# Nearest to had: pasiphae, mockingly, called, killed, foremost, cursed, honneur, allies,
# Nearest to he: father, humane, virchow, extremist, theophylline, appointment, polgar, adamawa,
# Nearest to up: endangering, gondor, ticket, toaster, picatinny, revel, chronica, cossacks,
# Nearest to or: probes, hmso, bomarc, mnemonic, arguments, secularism, psychologists, shutting,
# Nearest to no: septuagint, divan, tandy, elfland, wares, mcintosh, poverty, ensues,
# Nearest to who: homoerotic, purse, adolescent, arrested, impregnate, sino, allah, authority,
# Nearest to there: turkic, eurocheque, less, grunt, kalmar, permits, aran, blocking,
# Nearest to be: isomorphic, solicits, grasp, puts, deflation, proofs, the, conducting,
# Nearest to engineering: pin, impulses, buyer, enhancements, exemplify, gestational, unholy, transient,
# Nearest to instance: easily, aspirin, brotherhood, hafiz, second, preprocessor, porch, setup,
# Nearest to egypt: proletarian, major, gutted, exception, toontown, rajputs, gtc, geist,
# Nearest to report: numismatics, correspondance, dra, wai, piper, gallon, relocated, allegro,
# Nearest to accepted: jovis, myth, nations, seeking, says, cheddar, had, restoring,
# Nearest to numerous: hmas, sintering, uncertain, fachhochschule, fgm, cathode, masters, brokers,
# Nearest to cost: dummy, rissa, dojo, inviolable, microbiologist, shingon, pasok, optically,
# Nearest to orthodox: worship, denomination, oriental, ecumenical, unequalled, hereford, probl, unusable,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3519 0.2155 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3023 0.2077 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4117 0.2030 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3874 0.2028 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3868 0.2034 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3190 0.2034 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3119 0.2026 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3639 0.2028 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2553 0.2044 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3070 0.2032 sec/batch
# Nearest to had: pasiphae, mockingly, honneur, killed, called, when, cursed, normans,
# Nearest to he: humane, father, virchow, man, extremist, paraphrasing, unsuccessful, him,
# Nearest to up: endangering, move, gondor, toaster, nurturing, cossacks, ticket, picatinny,
# Nearest to or: probes, secularism, hmso, arguments, mnemonic, detailing, bomarc, chrismation,
# Nearest to no: septuagint, divan, ensues, tandy, poverty, females, elfland, mcintosh,
# Nearest to who: purse, homoerotic, adolescent, allah, impregnate, arrested, soylent, authority,
# Nearest to there: turkic, eurocheque, less, terminally, akhmatova, permits, kalmar, grunt,
# Nearest to be: isomorphic, solicits, grasp, puts, deflation, conducting, historically, the,
# Nearest to engineering: pin, impulses, buyer, exemplify, enhancements, gestational, unholy, transient,
# Nearest to instance: easily, aspirin, brotherhood, hafiz, preprocessor, visible, attribute, second,
# Nearest to egypt: major, proletarian, gutted, toontown, exception, rajputs, sardinia, invading,
# Nearest to report: numismatics, correspondance, dra, wai, piper, gallon, relocated, madre,
# Nearest to accepted: jovis, nations, myth, seeking, cheddar, farnham, had, ei,
# Nearest to numerous: sintering, fgm, hmas, uncertain, fachhochschule, brokers, cathode, synthesized,
# Nearest to cost: dummy, dojo, rissa, inviolable, costs, pasok, shingon, bubiyan,
# Nearest to orthodox: denomination, worship, unequalled, unusable, ecumenical, probl, hereford, oriental,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3402 0.2047 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3098 0.2054 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3417 0.0935 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2586 0.2030 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2759 0.2052 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2624 0.2040 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2241 0.2046 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2289 0.2130 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2357 0.2024 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1944 0.2072 sec/batch
# Nearest to had: pasiphae, honneur, when, cursed, killed, called, mockingly, foremost,
# Nearest to he: father, humane, virchow, him, unsuccessful, extremist, southsea, man,
# Nearest to up: gondor, picatinny, toaster, move, endangering, ticket, rotated, nurturing,
# Nearest to or: probes, secularism, mnemonic, batches, bomarc, hmso, chrismation, psychotic,
# Nearest to no: ensues, septuagint, females, poverty, tandy, divan, elfland, convertible,
# Nearest to who: purse, adolescent, homoerotic, impregnate, beloved, arrested, age, soylent,
# Nearest to there: turkic, eurocheque, hispanic, terminally, less, kalmar, ideologue, retrospectively,
# Nearest to be: isomorphic, grasp, solicits, puts, deflation, conducting, consulted, can,
# Nearest to engineering: pin, impulses, buyer, enhancements, gestational, exemplify, unholy, iterative,
# Nearest to instance: aspirin, easily, brotherhood, hafiz, preprocessor, porch, attribute, remained,
# Nearest to egypt: proletarian, toontown, rajputs, gutted, invading, major, sardinia, crimean,
# Nearest to report: numismatics, correspondance, wai, dra, piper, demarcated, mozambican, relocated,
# Nearest to accepted: jovis, nations, myth, cheddar, seeking, confession, ei, authorising,
# Nearest to numerous: fgm, sintering, hmas, brokers, cathode, uncertain, angkor, synthesized,
# Nearest to cost: dummy, dojo, costs, rissa, inviolable, bubiyan, pasok, bios,
# Nearest to orthodox: denomination, unequalled, ecumenical, worship, oriental, probl, hereford, unusable,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2933 0.2219 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2556 0.2144 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2356 0.2189 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1313 0.2090 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1896 0.2233 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1622 0.2242 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1795 0.2183 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1886 0.2116 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2143 0.2002 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1987 0.2003 sec/batch
# Nearest to had: when, cursed, honneur, pasiphae, foremost, mockingly, called, killed,
# Nearest to he: humane, virchow, father, him, brennan, southsea, cruel, kate,
# Nearest to up: picatinny, toaster, move, rotated, gondor, wycliffe, chronica, endangering,
# Nearest to or: with, probes, mnemonic, secularism, batches, bomarc, psychotic, detailing,
# Nearest to no: ensues, septuagint, divan, females, poverty, powerup, roark, elfland,
# Nearest to who: adolescent, purse, homoerotic, beloved, soylent, arrested, impregnate, belated,
# Nearest to there: turkic, eurocheque, hispanic, isomorphisms, terminally, analyses, kalmar, spawned,
# Nearest to be: isomorphic, puts, grasp, can, deflation, consulted, solicits, whistle,
# Nearest to engineering: buyer, impulses, pin, iterative, gestational, exemplify, enhancements, unholy,
# Nearest to instance: aspirin, easily, preprocessor, brotherhood, subsystems, attribute, hafiz, existent,
# Nearest to egypt: proletarian, rajputs, toontown, invading, sardinia, gutted, major, cacique,
# Nearest to report: numismatics, correspondance, wai, dra, piper, demarcated, berthollet, allegro,
# Nearest to accepted: jovis, nations, myth, cheddar, says, confession, seeking, farnham,
# Nearest to numerous: sintering, hmas, fgm, brokers, uncertain, cathode, masters, angkor,
# Nearest to cost: dojo, dummy, costs, rissa, inviolable, purebred, bubiyan, pasok,
# Nearest to orthodox: unequalled, ecumenical, denomination, oriental, worship, probl, catholic, unusable,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2031 0.2075 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2486 0.2073 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1618 0.2148 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1765 0.2111 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1807 0.2247 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1779 0.2169 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1950 0.2080 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1829 0.2078 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1437 0.2104 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2030 0.2174 sec/batch
# Nearest to had: when, called, cursed, honneur, pasiphae, endeavors, mockingly, time,
# Nearest to he: humane, virchow, father, him, brennan, unsuccessful, man, his,
# Nearest to up: picatinny, gondor, rotated, toaster, healed, chronica, endangering, ticket,
# Nearest to or: secularism, mnemonic, chrismation, psychotic, with, recall, batches, places,
# Nearest to no: septuagint, powerup, operands, divan, ensues, elfland, roark, females,
# Nearest to who: homoerotic, purse, belated, adolescent, impregnate, soylent, beloved, conventual,
# Nearest to there: turkic, eurocheque, isomorphisms, hispanic, kalmar, akhmatova, analyses, aran,
# Nearest to be: isomorphic, grasp, puts, deflation, can, consulted, solicits, displaying,
# Nearest to engineering: buyer, iterative, impulses, pin, exemplify, enhancements, gestational, compaq,
# Nearest to instance: aspirin, easily, preprocessor, brotherhood, attribute, suck, subsystems, porch,
# Nearest to egypt: proletarian, rajputs, toontown, major, invading, cacique, sardinia, gutted,
# Nearest to report: numismatics, correspondance, dra, wai, piper, demarcated, allegro, relocated,
# Nearest to accepted: nations, jovis, authorising, cheddar, myth, bakassi, confession, seeking,
# Nearest to numerous: sintering, hmas, fgm, uncertain, brokers, synthesized, angkor, hark,
# Nearest to cost: costs, pasok, dojo, rissa, inviolable, dummy, bubiyan, microbiologist,
# Nearest to orthodox: ecumenical, oriental, denomination, unequalled, probl, worship, unusable, catholic,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2293 0.2219 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1851 0.2191 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2115 0.2161 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1632 0.2158 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1505 0.2206 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1330 0.2269 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1854 0.2216 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1282 0.2291 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1837 0.2162 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2311 0.2090 sec/batch
# Nearest to had: called, when, honneur, died, time, pasiphae, mockingly, he,
# Nearest to he: him, unsuccessful, his, virchow, humane, paraphrasing, kate, father,
# Nearest to up: gondor, toaster, healed, ticket, picatinny, rotated, endangering, cossacks,
# Nearest to or: secularism, chrismation, mnemonic, detailing, is, batches, psychologists, with,
# Nearest to no: septuagint, divan, ensues, elfland, roark, powerup, females, wares,
# Nearest to who: adolescent, beloved, purse, impregnate, belated, homoerotic, those, conventual,
# Nearest to there: turkic, eurocheque, hispanic, kalmar, akhmatova, isomorphisms, term, terminally,
# Nearest to be: isomorphic, puts, grasp, can, consulted, court, deflation, solicits,
# Nearest to engineering: buyer, impulses, iterative, pin, cousteau, compaq, exemplify, gestational,
# Nearest to instance: aspirin, easily, brotherhood, preprocessor, suck, existent, porch, attribute,
# Nearest to egypt: rajputs, proletarian, invading, major, toontown, emitter, reynolds, gutted,
# Nearest to report: numismatics, correspondance, dra, wai, piper, demarcated, liquidated, relocated,
# Nearest to accepted: nations, jovis, encyclical, authorising, bentsen, wootton, cheddar, myth,
# Nearest to numerous: sintering, uncertain, brokers, hmas, fgm, hark, synthesized, cathode,
# Nearest to cost: dojo, pasok, costs, inviolable, rissa, dummy, optically, purebred,
# Nearest to orthodox: ecumenical, denomination, oriental, unequalled, probl, codification, worship, unusable,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2359 0.2104 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1735 0.2078 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1536 0.2048 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1684 0.2081 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0601 0.2021 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1433 0.2022 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1610 0.2015 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1479 0.2018 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1850 0.0385 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1407 0.2016 sec/batch
# Nearest to had: called, when, nsdap, pasiphae, honneur, he, cursed, multivectors,
# Nearest to he: his, him, humane, virchow, unsuccessful, paraphrasing, idleness, extremist,
# Nearest to up: picatinny, toaster, rotated, chronica, healed, ticket, endangering, gondor,
# Nearest to or: with, mnemonic, is, batches, secularism, detailing, chrismation, psychotic,
# Nearest to no: septuagint, divan, roark, elfland, ensues, females, convertible, tandy,
# Nearest to who: purse, impregnate, adolescent, belated, ffg, homoerotic, harshness, conventual,
# Nearest to there: eurocheque, turkic, hispanic, isomorphisms, tic, spawned, terminally, term,
# Nearest to be: can, isomorphic, puts, grasp, deflation, consulted, solicits, court,
# Nearest to engineering: iterative, impulses, buyer, pin, compaq, calculator, transient, cousteau,
# Nearest to instance: aspirin, easily, preprocessor, brotherhood, allegiances, suck, attribute, existent,
# Nearest to egypt: rajputs, proletarian, major, emitter, toontown, reynolds, invading, breathed,
# Nearest to report: dra, numismatics, correspondance, wai, piper, liquidated, demarcated, relocated,
# Nearest to accepted: nations, jovis, encyclical, bentsen, authorising, cheddar, vall, ordinances,
# Nearest to numerous: sintering, uncertain, fgm, hmas, brokers, hark, synthesized, angkor,
# Nearest to cost: costs, dojo, inviolable, pasok, dummy, rissa, optically, ivb,
# Nearest to orthodox: ecumenical, denomination, probl, unequalled, oriental, unusable, codification, worship,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0693 0.2025 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0724 0.2023 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1032 0.2017 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0853 0.2014 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1074 0.2043 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0436 0.2018 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0867 0.2045 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1085 0.2018 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1427 0.2016 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0471 0.2016 sec/batch
# Nearest to had: when, called, he, cursed, pasiphae, honneur, choo, time,
# Nearest to he: his, him, unsuccessful, virchow, had, extremist, idleness, father,
# Nearest to up: toaster, picatinny, ticket, rotated, healed, gondor, endangering, move,
# Nearest to or: with, mnemonic, is, batches, secularism, places, detailing, shutting,
# Nearest to no: ensues, septuagint, females, roark, enslave, convertible, respectful, thyself,
# Nearest to who: purse, those, impregnate, ffg, adolescent, beloved, age, conventual,
# Nearest to there: turkic, eurocheque, hispanic, isomorphisms, mpd, term, tic, spawned,
# Nearest to be: can, grasp, court, isomorphic, puts, consulted, whistle, deflation,
# Nearest to engineering: iterative, impulses, buyer, compaq, cousteau, transient, calculator, stalwart,
# Nearest to instance: aspirin, easily, preprocessor, allegiances, suck, porch, brotherhood, ruled,
# Nearest to egypt: proletarian, rajputs, emitter, major, reynolds, toontown, breathed, invading,
# Nearest to report: numismatics, correspondance, dra, piper, wai, liquidated, demarcated, gov,
# Nearest to accepted: jovis, nations, ordinances, pervading, encyclical, confession, cheddar, reductive,
# Nearest to numerous: sintering, uncertain, fgm, hmas, hark, brokers, synthesized, californian,
# Nearest to cost: costs, dojo, pasok, inviolable, dummy, rissa, optically, mmx,
# Nearest to orthodox: ecumenical, denomination, probl, oriental, unequalled, unusable, baptized, codification,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0340 0.2025 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0195 0.2018 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0525 0.2007 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0668 0.2014 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0967 0.2013 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0480 0.2013 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0784 0.2007 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1179 0.2015 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0611 0.2013 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0526 0.2019 sec/batch
# Nearest to had: when, called, retirement, honneur, choo, time, he, cursed,
# Nearest to he: his, him, virchow, southsea, idleness, unsuccessful, father, had,
# Nearest to up: toaster, picatinny, rotated, healed, ticket, gondor, move, chronica,
# Nearest to or: is, mnemonic, with, psychotic, places, chrismation, detailing, batches,
# Nearest to no: ensues, females, septuagint, roark, enslave, powerup, elfland, thyself,
# Nearest to who: impregnate, conventual, those, tacticus, beloved, purse, soylent, ffg,
# Nearest to there: hispanic, isomorphisms, turkic, eurocheque, term, tic, spawned, are,
# Nearest to be: can, isomorphic, this, grasp, puts, consulted, deflation, desired,
# Nearest to engineering: iterative, college, impulses, buyer, biomedical, calculator, postgraduate, transient,
# Nearest to instance: aspirin, easily, preprocessor, allegiances, suck, noon, brotherhood, attribute,
# Nearest to egypt: major, rajputs, proletarian, emitter, invading, reynolds, egyptian, cacique,
# Nearest to report: correspondance, dra, numismatics, piper, wai, assessment, gov, liquidated,
# Nearest to accepted: nations, jovis, authorising, transformational, bentsen, vall, farnham, cheddar,
# Nearest to numerous: sintering, uncertain, fgm, hark, hmas, californian, brokers, synthesized,
# Nearest to cost: costs, dojo, pasok, dummy, optically, inviolable, rissa, ivb,
# Nearest to orthodox: ecumenical, oriental, denomination, probl, catholic, unequalled, unusable, codification,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0466 0.2023 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0815 0.2015 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0831 0.2015 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0514 0.2008 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0748 0.2137 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0865 0.2042 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0644 0.2067 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0669 0.2091 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1007 0.2065 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0732 0.2049 sec/batch
# Nearest to had: when, called, nsdap, honneur, he, retirement, time, pasiphae,
# Nearest to he: his, him, virchow, father, after, idleness, inaction, southsea,
# Nearest to up: toaster, picatinny, rotated, healed, gondor, ticket, move, chronica,
# Nearest to or: is, mnemonic, with, chrismation, secularism, psychotic, see, diaconate,
# Nearest to no: septuagint, ensues, elfland, females, powerup, roark, inversely, operands,
# Nearest to who: those, impregnate, purse, conventual, beloved, archangels, tacticus, adolescent,
# Nearest to there: turkic, hispanic, isomorphisms, eurocheque, term, are, mpd, aran,
# Nearest to be: whistle, isomorphic, consulted, can, deflation, court, grasp, puts,
# Nearest to engineering: iterative, impulses, college, buyer, biomedical, calculator, transient, postgraduate,
# Nearest to instance: aspirin, allegiances, easily, preprocessor, noon, ruled, suck, prerogatives,
# Nearest to egypt: proletarian, major, rajputs, emitter, reynolds, egyptian, invading, historian,
# Nearest to report: dra, correspondance, numismatics, gov, wai, piper, assessment, liquidated,
# Nearest to accepted: nations, encyclical, authorising, jovis, bentsen, vall, wootton, myth,
# Nearest to numerous: sintering, uncertain, hark, fgm, hmas, animosity, brokers, kitchener,
# Nearest to cost: costs, pasok, dojo, inviolable, rissa, dummy, ivb, optically,
# Nearest to orthodox: ecumenical, oriental, probl, denomination, unequalled, unusable, baptized, eccleston,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0285 0.2052 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9873 0.2039 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0391 0.2034 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0761 0.2058 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0767 0.2092 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1298 0.2056 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1463 0.2043 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0313 0.2053 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0436 0.2035 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0654 0.2115 sec/batch
# Nearest to had: called, honneur, when, retirement, nsdap, konoe, he, time,
# Nearest to he: his, virchow, him, distraught, idleness, paraphrasing, after, southsea,
# Nearest to up: toaster, rotated, healed, picatinny, ticket, chronica, cossacks, gondor,
# Nearest to or: is, mnemonic, with, chrismation, units, hourglass, psychotic, specified,
# Nearest to no: septuagint, females, ensues, elfland, roark, powerup, inversely, respectful,
# Nearest to who: conventual, purse, those, impregnate, tacticus, beloved, sino, archangels,
# Nearest to there: turkic, hispanic, isomorphisms, eurocheque, mpd, are, term, tic,
# Nearest to be: whistle, consulted, can, isomorphic, this, deflation, court, grasp,
# Nearest to engineering: iterative, impulses, college, biomedical, calculator, buyer, postgraduate, cousteau,
# Nearest to instance: easily, aspirin, allegiances, preprocessor, noon, porch, prerogatives, attribute,
# Nearest to egypt: emitter, rajputs, proletarian, major, reynolds, egyptian, jibril, invading,
# Nearest to report: dra, correspondance, numismatics, wai, piper, assessment, gov, demarcated,
# Nearest to accepted: encyclical, bentsen, nations, authorising, on, vall, transformational, ei,
# Nearest to numerous: sintering, uncertain, hark, fgm, synthesized, hmas, animosity, hun,
# Nearest to cost: costs, inviolable, dojo, pasok, dummy, ivb, optically, rissa,
# Nearest to orthodox: ecumenical, probl, oriental, denomination, unequalled, unusable, eccleston, hereford,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9846 0.2099 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0455 0.2036 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0418 0.2166 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0414 0.2038 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0915 0.2034 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0650 0.1872 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0254 0.2034 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9936 0.2041 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0021 0.2049 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9756 0.2116 sec/batch
# Nearest to had: he, called, when, nsdap, retirement, konoe, pasiphae, time,
# Nearest to he: his, him, virchow, had, father, after, idleness, distraught,
# Nearest to up: toaster, rotated, picatinny, healed, move, ticket, endangering, chronica,
# Nearest to or: is, mnemonic, with, chrismation, hourglass, units, diaconate, detailing,
# Nearest to no: septuagint, roark, females, elfland, ensues, powerup, inversely, not,
# Nearest to who: impregnate, beloved, those, conventual, purse, adolescent, shaitan, docetism,
# Nearest to there: hispanic, turkic, isomorphisms, eurocheque, term, mpd, tic, are,
# Nearest to be: consulted, can, grasp, deflation, whistle, isomorphic, this, desired,
# Nearest to engineering: iterative, college, impulses, calculator, biomedical, postgraduate, dummett, compaq,
# Nearest to instance: aspirin, allegiances, preprocessor, easily, existent, noon, prerogatives, suck,
# Nearest to egypt: emitter, rajputs, egyptian, proletarian, reynolds, major, historian, toontown,
# Nearest to report: dra, correspondance, numismatics, gov, piper, wai, assessment, demarcated,
# Nearest to accepted: encyclical, authorising, jovis, nations, bentsen, vall, on, transformational,
# Nearest to numerous: sintering, hark, fgm, uncertain, synthesized, californian, hmas, hun,
# Nearest to cost: costs, inviolable, pasok, ivb, dojo, optically, mmx, rissa,
# Nearest to orthodox: ecumenical, oriental, probl, unequalled, denomination, unusable, eccleston, forbidden,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9985 0.2142 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9391 0.2012 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0097 0.2007 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0260 0.2044 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0074 0.2196 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9824 0.2150 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9116 0.2047 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9622 0.2178 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9556 0.2258 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9722 0.2208 sec/batch
# Nearest to had: nsdap, called, when, time, retirement, konoe, he, rassemblement,
# Nearest to he: his, him, distraught, virchow, idleness, father, had, himself,
# Nearest to up: toaster, picatinny, rotated, move, healed, chronica, running, ticket,
# Nearest to or: is, with, mnemonic, from, billiard, hourglass, units, have,
# Nearest to no: ensues, females, septuagint, roark, powerup, not, elfland, respectful,
# Nearest to who: those, impregnate, them, conventual, tacticus, ffg, soylent, purse,
# Nearest to there: hispanic, turkic, isomorphisms, eurocheque, term, are, permits, except,
# Nearest to be: can, this, isomorphic, consulted, whistle, deflation, desired, actions,
# Nearest to engineering: college, iterative, impulses, biomedical, calculator, postgraduate, cousteau, institutes,
# Nearest to instance: aspirin, preprocessor, allegiances, existent, noon, prerogatives, easily, suck,
# Nearest to egypt: emitter, rajputs, historian, egyptian, reynolds, proletarian, shorthand, breathed,
# Nearest to report: dra, correspondance, numismatics, gov, piper, wai, nist, nih,
# Nearest to accepted: encyclical, on, authorising, nations, jovis, transformational, vall, outwit,
# Nearest to numerous: sintering, fgm, hark, uncertain, animosity, californian, hmas, brokers,
# Nearest to cost: costs, pasok, ivb, inviolable, dojo, optically, mmx, rissa,
# Nearest to orthodox: ecumenical, unequalled, oriental, denomination, probl, unusable, catholic, baptized,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0105 0.2208 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9974 0.2249 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9831 0.2290 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0252 0.2168 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0412 0.2413 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9523 0.2180 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0083 0.2236 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0045 0.2189 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0167 0.2102 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9826 0.2108 sec/batch
# Nearest to had: he, nsdap, called, retirement, when, time, konoe, ludlow,
# Nearest to he: his, him, had, father, virchow, distraught, idleness, after,
# Nearest to up: toaster, healed, move, picatinny, ticket, running, rotated, chronica,
# Nearest to or: is, with, mnemonic, chrismation, psychotic, units, specified, obliged,
# Nearest to no: powerup, operands, septuagint, elfland, females, roark, inversely, ensues,
# Nearest to who: soylent, those, impregnate, them, conventual, tacticus, archangels, beloved,
# Nearest to there: hispanic, isomorphisms, term, eurocheque, turkic, are, now, missal,
# Nearest to be: this, whistle, can, consulted, pompous, isomorphic, deflation, desired,
# Nearest to engineering: college, iterative, calculator, impulses, biomedical, postgraduate, disciplines, technology,
# Nearest to instance: preprocessor, allegiances, aspirin, easily, prerogatives, noon, suck, existent,
# Nearest to egypt: emitter, rajputs, reynolds, egyptian, proletarian, major, historian, shorthand,
# Nearest to report: dra, correspondance, gov, numismatics, nist, piper, assessment, wai,
# Nearest to accepted: encyclical, on, had, transformational, jovis, masonry, vall, authorising,
# Nearest to numerous: hark, sintering, fgm, uncertain, genres, synthesized, hmas, animosity,
# Nearest to cost: costs, inviolable, pasok, ivb, dojo, pricing, optically, rissa,
# Nearest to orthodox: ecumenical, oriental, unequalled, probl, catholic, baptized, denomination, unusable,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0122 0.2094 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0050 0.2096 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0027 0.2066 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0058 0.2054 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0435 0.2017 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9971 0.2012 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9820 0.2046 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9543 0.2064 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9615 0.2084 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0325 0.2062 sec/batch
# Nearest to had: nsdap, he, called, time, retirement, when, was, reunions,
# Nearest to he: his, him, had, father, distraught, idleness, unsuccessful, himself,
# Nearest to up: toaster, healed, picatinny, chronica, endangering, rotated, move, running,
# Nearest to or: is, with, mnemonic, chrismation, specified, see, are, from,
# Nearest to no: elfland, not, septuagint, powerup, females, is, ensues, torlakian,
# Nearest to who: those, them, impregnate, conventual, tacticus, family, soylent, beloved,
# Nearest to there: hispanic, isomorphisms, are, term, turkic, eurocheque, now, permits,
# Nearest to be: can, this, whistle, isomorphic, deflation, desired, workgroup, for,
# Nearest to engineering: college, impulses, iterative, calculator, biomedical, postgraduate, buyer, technology,
# Nearest to instance: allegiances, preprocessor, aspirin, noon, easily, prerogatives, suck, existent,
# Nearest to egypt: emitter, rajputs, reynolds, egyptian, proletarian, historian, major, breathed,
# Nearest to report: dra, gov, assessment, correspondance, numismatics, nist, piper, demarcated,
# Nearest to accepted: encyclical, had, transformational, nations, on, masonry, strassburg, jovis,
# Nearest to numerous: hark, sintering, synthesized, genres, fgm, hun, uncertain, californian,
# Nearest to cost: costs, pasok, inviolable, ivb, dojo, rissa, optically, multiplied,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8213 0.1996 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8745 0.1998 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8887 0.1997 sec/batch
# Nearest to had: later, nsdap, he, retirement, was, him, when, called,
# Nearest to he: his, him, graduated, attended, had, went, father, himself,
# Nearest to up: out, toaster, move, run, at, cheerfully, back, gill,
# Nearest to or: is, with, are, other, from, a, have, some,
# Nearest to no: are, not, import, all, duplicate, is, this, sanj,
# Nearest to who: those, their, them, living, beloved, tacticus, soylent, josh,
# Nearest to there: have, are, few, every, argo, number, where, isomorphisms,
# Nearest to be: that, for, are, this, the, have, is, often,
# Nearest to engineering: disciplines, engineers, impulses, biomedical, cpsu, mechatronics, postgraduate, college,
# Nearest to instance: asparagine, existent, scuba, any, preprocessor, produce, toole, argand,
# Nearest to egypt: egyptian, emitter, coptic, historian, cxd, egyptians, reynolds, breathed,
# Nearest to report: nist, assessment, declassified, correspondance, piper, veracity, fbi, gov,
# Nearest to accepted: had, encyclical, rejoin, bivector, doctorate, authorising, recite, farnham,
# Nearest to numerous: genres, synthesized, patton, several, many, hark, sintering, element,
# Nearest to cost: costs, edmond, earning, bookkeeping, inviolable, mears, rissa, caches,
# Nearest to orthodox: ecumenical, unusable, oriental, unequalled, eccleston, churches, catholic, madam,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8343 0.2007 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8508 0.2044 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8653 0.2003 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8652 0.1998 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8719 0.1999 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8618 0.2010 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8667 0.2008 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8518 0.2011 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8927 0.1998 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8532 0.1997 sec/batch
# Nearest to had: later, nsdap, was, he, retirement, accepted, reunions, him,
# Nearest to he: his, him, graduated, attended, himself, had, father, went,
# Nearest to up: out, move, toaster, cheerfully, alone, diphthong, at, back,
# Nearest to or: is, with, other, from, are, a, and, any,
# Nearest to no: import, duplicate, not, sanj, jargon, are, all, is,
# Nearest to who: those, them, their, living, krzysztof, family, tacticus, beloved,
# Nearest to there: are, have, few, argo, where, every, number, other,
# Nearest to be: that, for, the, are, this, it, have, also,
# Nearest to engineering: impulses, disciplines, engineers, biomedical, cpsu, mechatronics, postgraduate, gestational,
# Nearest to instance: asparagine, existent, scuba, preprocessor, toole, easily, munic, suck,
# Nearest to egypt: egyptian, emitter, historian, coptic, cxd, reynolds, cctld, breathed,
# Nearest to report: declassified, nist, assessment, piper, correspondance, fbi, gov, veracity,
# Nearest to accepted: had, encyclical, strassburg, atheling, bivector, authorising, doctorate, rejoin,
# Nearest to numerous: genres, patton, many, several, synthesized, hark, ecclesial, most,
# Nearest to cost: costs, edmond, pasok, inviolable, multiplied, earning, bookkeeping, outweigh,
# Nearest to orthodox: ecumenical, unusable, oriental, unequalled, eccleston, churches, madam, patriarchate,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8557 0.2008 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8355 0.2207 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8345 0.2023 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8214 0.2087 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9029 0.1996 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8252 0.2006 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9781 0.1998 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8967 0.1994 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8912 0.1991 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8010 0.1993 sec/batch
# Nearest to had: later, was, nsdap, he, worked, accepted, before, became,
# Nearest to he: his, him, graduated, attended, had, was, went, himself,
# Nearest to up: out, toaster, move, diphthong, back, alone, responded, cheerfully,
# Nearest to or: is, with, are, have, and, from, some, one,
# Nearest to no: import, duplicate, sanj, are, jargon, all, torlakian, not,
# Nearest to who: those, them, their, living, family, whom, krzysztof, tacticus,
# Nearest to there: have, are, few, argo, where, every, number, make,
# Nearest to be: that, for, this, are, have, it, is, also,
# Nearest to engineering: impulses, engineers, biomedical, disciplines, cpsu, mechatronics, postgraduate, generalitat,
# Nearest to instance: asparagine, existent, scuba, preprocessor, toole, produce, easily, suck,
# Nearest to egypt: egyptian, emitter, coptic, historian, cxd, reynolds, egyptians, breathed,
# Nearest to report: declassified, assessment, nist, piper, correspondance, fbi, gov, ipcc,
# Nearest to accepted: had, encyclical, rejoin, doctorate, authorising, bivector, flagstaff, negotiating,
# Nearest to numerous: genres, many, several, patton, synthesized, ecclesial, most, clans,
# Nearest to cost: costs, edmond, inviolable, earning, pasok, multiplied, bookkeeping, hellraiser,
# Nearest to orthodox: ecumenical, unusable, unequalled, eccleston, oriental, routine, karaites, ukrainian,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7790 0.1996 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8557 0.1990 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7759 0.1999 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8849 0.1997 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8528 0.1994 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8724 0.1993 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9018 0.1136 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8363 0.1995 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8598 0.1997 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8447 0.2008 sec/batch
# Nearest to had: later, was, he, nsdap, him, made, when, his,
# Nearest to he: his, him, had, was, himself, went, graduated, after,
# Nearest to up: toaster, out, move, for, are, back, diphthong, alone,
# Nearest to or: is, with, are, have, a, and, some, any,
# Nearest to no: import, duplicate, not, all, jargon, elfland, are, sanj,
# Nearest to who: those, their, them, whom, beloved, living, they, tacticus,
# Nearest to there: are, have, few, where, argo, every, isomorphisms, number,
# Nearest to be: that, for, have, this, are, it, is, the,
# Nearest to engineering: impulses, engineers, disciplines, biomedical, mechatronics, cpsu, generalitat, gestational,
# Nearest to instance: asparagine, existent, scuba, toole, any, preprocessor, produce, aspirin,
# Nearest to egypt: egyptian, emitter, cxd, historian, coptic, reynolds, breathed, egyptians,
# Nearest to report: declassified, nist, assessment, piper, correspondance, fbi, ipcc, veracity,
# Nearest to accepted: had, encyclical, doctorate, rejoin, conveyed, atheling, noting, outwit,
# Nearest to numerous: genres, patton, many, synthesized, several, ecclesial, element, sintering,
# Nearest to cost: costs, edmond, bookkeeping, earning, inviolable, pasok, hellraiser, dockyard,
# Nearest to orthodox: ecumenical, unusable, unequalled, eccleston, oriental, karaites, ukrainian, routine,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8220 0.1999 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8284 0.1984 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8314 0.1980 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8051 0.1980 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8803 0.1994 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8362 0.2000 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8985 0.2004 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7511 0.2010 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8187 0.2001 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7924 0.1998 sec/batch
# Nearest to had: later, was, he, nsdap, him, retirement, when, made,
# Nearest to he: his, him, attended, went, graduated, had, himself, father,
# Nearest to up: toaster, out, move, back, diphthong, before, make, cheerfully,
# Nearest to or: is, with, a, are, other, from, some, have,
# Nearest to no: import, not, are, all, this, duplicate, is, even,
# Nearest to who: those, their, them, living, family, they, members, beloved,
# Nearest to there: are, have, few, that, where, number, every, other,
# Nearest to be: that, for, this, is, the, have, are, a,
# Nearest to engineering: impulses, disciplines, engineers, biomedical, cpsu, mechatronics, gestational, ayrton,
# Nearest to instance: asparagine, existent, any, preprocessor, scuba, is, munic, has,
# Nearest to egypt: egyptian, emitter, cxd, historian, coptic, reynolds, breathed, kulm,
# Nearest to report: declassified, nist, assessment, piper, correspondance, fbi, veracity, ipcc,
# Nearest to accepted: encyclical, had, doctorate, noting, rejoin, outwit, bivector, jacob,
# Nearest to numerous: genres, many, patton, several, ecclesial, synthesized, upkeep, mukhabarat,
# Nearest to cost: costs, edmond, bookkeeping, pasok, inviolable, optically, hellraiser, earning,
# Nearest to orthodox: unusable, ecumenical, unequalled, eccleston, oriental, churches, madam, routine,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7666 0.2018 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8346 0.2004 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8469 0.1995 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8099 0.2011 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8185 0.1992 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9155 0.2001 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8499 0.2009 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8310 0.1997 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8026 0.1997 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8590 0.2007 sec/batch
# Nearest to had: later, was, he, retirement, nsdap, reunions, made, him,
# Nearest to he: his, him, had, father, attended, graduated, himself, lecturer,
# Nearest to up: out, toaster, move, back, are, make, diphthong, alone,
# Nearest to or: is, with, other, are, a, have, often, some,
# Nearest to no: not, all, import, are, sanj, is, elfland, even,
# Nearest to who: those, their, them, family, beloved, they, living, tacticus,
# Nearest to there: are, have, where, few, every, other, that, argo,
# Nearest to be: that, for, are, this, the, is, have, as,
# Nearest to engineering: engineers, biomedical, disciplines, impulses, cpsu, mechatronics, postgraduate, college,
# Nearest to instance: existent, asparagine, scuba, preprocessor, toole, has, easily, munic,
# Nearest to egypt: egyptian, emitter, cxd, coptic, reynolds, historian, egyptians, cctld,
# Nearest to report: declassified, nist, assessment, correspondance, piper, fbi, gov, ipcc,
# Nearest to accepted: had, doctorate, encyclical, rejoin, urheimat, outwit, noting, application,
# Nearest to numerous: many, genres, several, patton, most, synthesized, ecclesial, hark,
# Nearest to cost: costs, bookkeeping, edmond, earning, optically, inviolable, hellraiser, pasok,
# Nearest to orthodox: ecumenical, churches, oriental, unusable, catholic, unequalled, eccleston, catholicism,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8400 0.2055 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8635 0.2000 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8086 0.2009 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8186 0.1995 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8632 0.1999 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8401 0.2001 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8117 0.1998 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8329 0.1998 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8135 0.2008 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7898 0.1993 sec/batch
# Nearest to had: later, was, he, nsdap, accepted, made, called, became,
# Nearest to he: his, him, had, attended, graduated, father, himself, went,
# Nearest to up: out, by, move, toaster, where, there, diphthong, back,
# Nearest to or: is, with, other, a, are, some, and, from,
# Nearest to no: import, not, all, duplicate, sanj, jargon, are, is,
# Nearest to who: those, their, them, living, family, they, whom, beloved,
# Nearest to there: have, are, where, few, that, other, number, in,
# Nearest to be: that, for, the, are, this, is, also, have,
# Nearest to engineering: impulses, biomedical, engineers, cpsu, disciplines, mechatronics, postgraduate, ayrton,
# Nearest to instance: existent, has, asparagine, scuba, toole, any, an, easily,
# Nearest to egypt: egyptian, emitter, cxd, coptic, historian, reynolds, egyptians, cctld,
# Nearest to report: declassified, assessment, nist, ipcc, correspondance, piper, fbi, gov,
# Nearest to accepted: had, encyclical, urheimat, rejoin, doctorate, negotiating, nouveaux, flagstaff,
# Nearest to numerous: many, several, genres, most, patton, synthesized, ecclesial, these,
# Nearest to cost: costs, bookkeeping, edmond, inviolable, earning, fighter, demain, optically,
# Nearest to orthodox: ecumenical, churches, unusable, oriental, unequalled, eccleston, catholic, catholicism,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8727 0.2007 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8111 0.2010 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9113 0.2003 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9212 0.2004 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8986 0.1996 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8199 0.2000 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7697 0.1965 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8511 0.1975 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7379 0.1978 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8513 0.1987 sec/batch
# Nearest to had: later, was, he, nsdap, made, became, worked, reunions,
# Nearest to he: his, him, attended, graduated, himself, went, had, father,
# Nearest to up: out, toaster, back, diphthong, where, move, for, make,
# Nearest to or: is, a, are, with, other, some, often, any,
# Nearest to no: import, not, duplicate, all, sanj, even, are, addis,
# Nearest to who: those, their, them, whom, family, living, they, tacticus,
# Nearest to there: are, have, where, few, that, make, number, other,
# Nearest to be: that, for, are, have, this, the, also, as,
# Nearest to engineering: impulses, biomedical, cpsu, disciplines, engineers, mechatronics, postgraduate, landon,
# Nearest to instance: asparagine, existent, has, an, scuba, is, any, preprocessor,
# Nearest to egypt: egyptian, emitter, cxd, coptic, historian, reynolds, egyptians, cctld,
# Nearest to report: declassified, assessment, nist, ipcc, piper, correspondance, washington, fbi,
# Nearest to accepted: had, rejoin, encyclical, doctorate, flagstaff, outwit, application, misplaced,
# Nearest to numerous: several, many, most, genres, patton, synthesized, monomers, upkeep,
# Nearest to cost: costs, edmond, bookkeeping, earning, inviolable, pasok, resell, increased,
# Nearest to orthodox: unusable, ecumenical, churches, eccleston, unequalled, oriental, routine, madam,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8590 0.1993 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8518 0.1980 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
